# %%
import statsmodels.api as sm
import pandas as pd
from patsy import dmatrices
df = sm.datasets.get_rdataset("Guerry", "HistData").data

# %%
df.columns
# Out:
# Index(['dept', 'Region', 'Department', 'Crime_pers', 'Crime_prop', 'Literacy',
#        'Donations', 'Infants', 'Suicides', 'MainCity', 'Wealth', 'Commerce',
#        'Clergy', 'Crime_parents', 'Infanticide', 'Donation_clergy', 'Lottery',
#        'Desertion', 'Instruction', 'Prostitutes', 'Distance', 'Area',
#        'Pop1831'],
#       dtype='object')

# %%
vars = ['Department','Lottery','Literacy', 'Wealth','Region']
df=df[vars]

# %%
df=df.dropna()

# %%
y, X = dmatrices('Lottery ~ Literacy + Wealth + Region', data=df, return_type='dataframe')

# %%
X
# Out:
#     Intercept  Region[T.E]  Region[T.N]  Region[T.S]  Region[T.W]  Literacy  \
# 0           1            1            0            0            0        37
# 1           1            0            1            0            0        51
# 2           1            0            0            0            0        13
# 3           1            1            0            0            0        46
# 4           1            1            0            0            0        69
# 5           1            0            0            1            0        27
# 6           1            0            1            0            0        67
# 7           1            0            0            1            0        18
# 8           1            1            0            0            0        59
# 9           1            0            0            1            0        34
# 10          1            0            0            1            0        31
# 11          1            0            0            1            0        38
# 12          1            0            1            0            0        52
# 13          1            0            0            0            0        31
# 14          1            0            0            0            1        36
# 15          1            0            0            0            1        39
# 16          1            0            0            0            0        13
# 17          1            0            0            0            0        12
# 18          1            1            0            0            0        60
# 19          1            0            0            0            1        16
# 20          1            0            0            0            0        23
# 21          1            0            0            0            1        18
# 22          1            1            0            0            0        73
# 23          1            1            0            0            0        42
# 24          1            0            1            0            0        51
# 25          1            0            0            0            0        54
# 26          1            0            0            0            1        15
# 27          1            0            0            1            0        40
# 28          1            0            0            1            0        31
# 29          1            0            0            1            0        38
# ..        ...          ...          ...          ...          ...       ...
# 55          1            0            0            0            0        20
# 56          1            0            1            0            0        45
# 57          1            0            1            0            0        54
# 58          1            0            1            0            0        45
# 59          1            0            1            0            0        49
# 60          1            0            0            0            0        19
# 61          1            0            0            0            1        47
# 62          1            0            0            1            0        53
# 63          1            0            0            1            0        31
# 64          1            1            0            0            0        62
# 65          1            1            0            0            0        71
# 66          1            1            0            0            0        45
# 67          1            1            0            0            0        59
# 68          1            1            0            0            0        32
# 69          1            0            0            0            0        30
# 70          1            0            1            0            0        71
# 71          1            0            1            0            0        43
# 72          1            0            1            0            0        54
# 73          1            0            1            0            0        56
# 74          1            0            0            0            1        41
# 75          1            0            1            0            0        44
# 76          1            0            0            1            0        20
# 77          1            0            0            1            0        25
# 78          1            0            0            1            0        23
# 79          1            0            0            1            0        37
# 80          1            0            0            0            1        28
# 81          1            0            0            0            1        25
# 82          1            0            0            0            0        13
# 83          1            1            0            0            0        62
# 84          1            0            0            0            0        47
#
#     Wealth
# 0       73
# 1       22
# 2       61
# 3       76
# 4       83
# 5       84
# 6       33
# 7       72
# 8       14
# 9       17
# 10      50
# 11       2
# 12      10
# 13      59
# 14      86
# 15      18
# 16      63
# 17      74
# 18      16
# 19      70
# 20      78
# 21      60
# 22      31
# 23      66
# 24      20
# 25      11
# 26      36
# 27      26
# 28      23
# 29      40
# ..     ...
# 55      44
# 56      28
# 57      15
# 58      35
# 59      45
# 60      51
# 61      79
# 62      85
# 63      71
# 64      46
# 65      58
# 66       6
# 67      69
# 68      49
# 69      41
# 70       1
# 71       3
# 72       4
# 73       5
# 74      39
# 75      21
# 76      47
# 77      29
# 78      43
# 79      64
# 80      56
# 81      68
# 82      67
# 83      82
# 84      30
#
# [85 rows x 7 columns]

# %%
mod = sm.OLS(y, X)
res=mod.fit()
print (res.summary())
sm.stats.linear_rainbow(res)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Lottery   R-squared:                       0.338
# Model:                            OLS   Adj. R-squared:                  0.287
# Method:                 Least Squares   F-statistic:                     6.636
# Date:                Wed, 18 Nov 2015   Prob (F-statistic):           1.07e-05
# Time:                        16:24:08   Log-Likelihood:                -375.30
# No. Observations:                  85   AIC:                             764.6
# Df Residuals:                      78   BIC:                             781.7
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept      38.6517      9.456      4.087      0.000        19.826    57.478
# Region[T.E]   -15.4278      9.727     -1.586      0.117       -34.793     3.938
# Region[T.N]   -10.0170      9.260     -1.082      0.283       -28.453     8.419
# Region[T.S]    -4.5483      7.279     -0.625      0.534       -19.039     9.943
# Region[T.W]   -10.0913      7.196     -1.402      0.165       -24.418     4.235
# Literacy       -0.1858      0.210     -0.886      0.378        -0.603     0.232
# Wealth          0.4515      0.103      4.390      0.000         0.247     0.656
# ==============================================================================
# Omnibus:                        3.049   Durbin-Watson:                   1.785
# Prob(Omnibus):                  0.218   Jarque-Bera (JB):                2.694
# Skew:                          -0.340   Prob(JB):                        0.260
# Kurtosis:                       2.454   Cond. No.                         371.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# (0.84723399761569096, 0.69979655436216437)

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot

print (__version__ )# requires version >= 1.9.0
init_notebook_mode() # run at the start of every ipython notebook to use plotly.offline
                     # this injects the plotly.js source files into the notebook
# Out:
# 1.8.12
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-28-d0b2eaaef726> in <module>()
#       4
#       5 print (__version__ )# requires version >= 1.9.0
# ----> 6 init_notebook_mode() # run at the start of every ipython notebook to use plotly.offline
#       7                      # this injects the plotly.js source files into the notebook
#
# /Users/linwood/anaconda/envs/py35/lib/python3.5/site-packages/plotly/offline/offline.py in init_notebook_mode()
#      65                           'Contact sales@plot.ly learn more about licensing.\n'
#      66                           'Questions? support@plot.ly.'
# ---> 67                           .format(source_path=PLOTLY_OFFLINE_BUNDLE))
#      68
#      69     global __PLOTLY_OFFLINE_INITIALIZED
#
# PlotlyError: Plotly Offline source file at /Users/linwood/.plotly/plotlyjs/plotly-ipython-offline-bundle.js is not found.
# If you have a Plotly Offline license, then try running plotly.offline.download_plotlyjs(url) with a licensed download url.
# Don't have a Plotly Offline license? Contact sales@plot.ly learn more about licensing.
# Questions? support@plot.ly.
